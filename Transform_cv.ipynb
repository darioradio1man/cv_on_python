# %%
from PIL import ImageFilter
import cv2
import numpy as np
from matplotlib import pyplot as plt
import sys
# %matplotlib inline
img = cv2.imread('KB_my_pics/2.jpg',1)  
#timage = cv2.imread('C:/Users/dario/Pictures/KB_my_pics/2.jpg',1)  
h,w = img.shape[:2]
plt.imshow(img,cmap='gray')
plt.show() 

#working with part of pictures
#r = cv2.selectROI(img)
#imCrop = img[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
#tempPicture = cv2.imshow("image", imCrop)
#cv2.waitKey()

#simple threshsolding 
#ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
#ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
#ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
#ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
#ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
#
#titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
#images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
# 
#for i in range(6):
#     plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
#     plt.title(titles[i])
#     plt.xticks([]),plt.yticks([]) 
#     
#plt.show()

#adaptive threshsolding
#grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
#image = cv2.medianBlur(grey, 1)
#ret,th1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
#th2 = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
# cv2.THRESH_BINARY,11,2)
#th3 = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, \
# cv2.THRESH_BINARY,11,2)
#
#titles = ['Original Image', 'Global Thresholding (v = 127)',
#          'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
#images = [img, th1, th2, th3] 
#for i in range(4):
#   plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
#   plt.title(titles[i])
#   plt.xticks([]),plt.yticks([])
#plt.show()

#ret1,th1 = cv2.threshold(img, 127,255, cv2.THRESH_BINARY)
#ret2,th2 = cv2.threshold(timage, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#gr = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
#blur = cv2.GaussianBlur(gr, (7,7), 1.5)
#ret3,th3 = cv2.threshold(gr, 0,255,  cv2.THRESH_OTSU)

#images = [img, 0, th1,
#          img, 0, th2,
#          blur, 0, th3]
#
#titles = ['Original Noisy Image','Histogram','Global Threshsolding (v = 127)',
#          'Original Noist Image','Histogram', "Otsu's Threshsolding",
#          'Gaussian filtered Image','Histogram', "Otsu's Threshsolding"]
#
#for i in range(3):
#    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3], 'gray')
#    plt.title(titles[i*3]),plt.xticks([]), plt.yticks([])
#    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
#    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
#    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2], 'gray')
#    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
#plt.show()


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
#gray = cv2.GaussianBlur(gray, (7, 7), 1.5) 
#blur = cv2.blur(gray, (2, 2))
#mblur = cv2.medianBlur(gray, 3)

laplacian = cv2.Laplacian(gray,cv2.CV_8U)
sobelx = cv2.Sobel(gray,cv2.CV_8U,1,0,ksize=5)
sobely = cv2.Sobel(gray,cv2.CV_8U,0,1,ksize=5)
edges = cv2.Canny(laplacian, 0, 50)
edges1 = cv2.Canny(sobelx, 0, 50) 
edges2 = cv2.Canny(sobely, 0, 50) 

plt.imshow(edges,cmap='gray')
plt.show()  
plt.imshow(edges1,cmap='gray')
plt.show()
plt.imshow(edges2,cmap='gray')
plt.show()

# %%
from PIL import ImageFilter
import cv2
import numpy as np
from matplotlib import pyplot as plt
import sys
# %matplotlib inline
img = cv2.imread('KB_my_pics/5.jpg',1)  
#timage = cv2.imread('C:/Users/dario/Pictures/KB_my_pics/2.jpg',1)  
h,w = img.shape[:2]
plt.imshow(img,cmap='gray')
plt.show() 

#working with part of pictures
#r = cv2.selectROI(img)
#imCrop = img[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
#tempPicture = cv2.imshow("image", imCrop)
#cv2.waitKey()

#simple threshsolding 
#ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
#ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
#ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
#ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
#ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
#
#titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
#images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
# 
#for i in range(6):
#     plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
#     plt.title(titles[i])
#     plt.xticks([]),plt.yticks([]) 
#     
#plt.show()

#adaptive threshsolding
#grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
#image = cv2.medianBlur(grey, 1)
#ret,th1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
#th2 = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
# cv2.THRESH_BINARY,11,2)
#th3 = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, \
# cv2.THRESH_BINARY,11,2)
#
#titles = ['Original Image', 'Global Thresholding (v = 127)',
#          'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
#images = [img, th1, th2, th3] 
#for i in range(4):
#   plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
#   plt.title(titles[i])
#   plt.xticks([]),plt.yticks([])
#plt.show()

#ret1,th1 = cv2.threshold(img, 127,255, cv2.THRESH_BINARY)
#ret2,th2 = cv2.threshold(timage, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#gr = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
#blur = cv2.GaussianBlur(gr, (7,7), 1.5)
#ret3,th3 = cv2.threshold(gr, 0,255,  cv2.THRESH_OTSU)

#images = [img, 0, th1,
#          img, 0, th2,
#          blur, 0, th3]
#
#titles = ['Original Noisy Image','Histogram','Global Threshsolding (v = 127)',
#          'Original Noist Image','Histogram', "Otsu's Threshsolding",
#          'Gaussian filtered Image','Histogram', "Otsu's Threshsolding"]
#
#for i in range(3):
#    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3], 'gray')
#    plt.title(titles[i*3]),plt.xticks([]), plt.yticks([])
#    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
#    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
#    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2], 'gray')
#    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
#plt.show()


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
#gray = cv2.GaussianBlur(gray, (7, 7), 1.5) 
blur = cv2.blur(gray, (5, 5))
#mblur = cv2.medianBlur(gray, 3)

laplacian = cv2.Laplacian(blur,cv2.CV_8U)
sobelx = cv2.Sobel(blur,cv2.CV_8U,1,0,ksize=7)
sobely = cv2.Sobel(blur,cv2.CV_8U,0,1,ksize=7)
edges = cv2.Canny(laplacian, 0, 50)
edges1 = cv2.Canny(sobelx, 0, 50) 
edges2 = cv2.Canny(sobely, 0, 50) 

plt.imshow(edges,cmap='gray')
plt.show()  
plt.imshow(edges1,cmap='gray')
plt.show()
plt.imshow(edges2,cmap='gray')
plt.show()

# %%
from PIL import ImageFilter
import cv2
import numpy as np
from matplotlib import pyplot as plt
import sys
# %matplotlib inline
img = cv2.imread('KB_my_pics/3.jpg',1)  
#timage = cv2.imread('C:/Users/dario/Pictures/KB_my_pics/2.jpg',1)  
h,w = img.shape[:2]
plt.imshow(img,cmap='gray')
plt.show() 

#working with part of pictures
#r = cv2.selectROI(img)
#imCrop = img[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
#tempPicture = cv2.imshow("image", imCrop)
#cv2.waitKey()

#simple threshsolding 
#ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
#ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
#ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
#ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
#ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
#
#titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
#images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
# 
#for i in range(6):
#     plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
#     plt.title(titles[i])
#     plt.xticks([]),plt.yticks([]) 
#     
#plt.show()

#adaptive threshsolding
#grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
#image = cv2.medianBlur(grey, 1)
#ret,th1 = cv2.threshold(image,127,255,cv2.THRESH_BINARY)
#th2 = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
# cv2.THRESH_BINARY,11,2)
#th3 = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, \
# cv2.THRESH_BINARY,11,2)
#
#titles = ['Original Image', 'Global Thresholding (v = 127)',
#          'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
#images = [img, th1, th2, th3] 
#for i in range(4):
#   plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
#   plt.title(titles[i])
#   plt.xticks([]),plt.yticks([])
#plt.show()

#ret1,th1 = cv2.threshold(img, 127,255, cv2.THRESH_BINARY)
#ret2,th2 = cv2.threshold(timage, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#gr = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
#blur = cv2.GaussianBlur(gr, (7,7), 1.5)
#ret3,th3 = cv2.threshold(gr, 0,255,  cv2.THRESH_OTSU)

#images = [img, 0, th1,
#          img, 0, th2,
#          blur, 0, th3]
#
#titles = ['Original Noisy Image','Histogram','Global Threshsolding (v = 127)',
#          'Original Noist Image','Histogram', "Otsu's Threshsolding",
#          'Gaussian filtered Image','Histogram', "Otsu's Threshsolding"]
#
#for i in range(3):
#    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3], 'gray')
#    plt.title(titles[i*3]),plt.xticks([]), plt.yticks([])
#    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
#    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
#    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2], 'gray')
#    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
#plt.show()


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
#gray = cv2.GaussianBlur(gray, (7, 7), 1.5) 
#blur = cv2.blur(gray, (5, 5))
mblur = cv2.medianBlur(gray, 1)

laplacian = cv2.Laplacian(mblur,cv2.CV_8U)
sobelx = cv2.Sobel(mblur,cv2.CV_8U,1,0,ksize=7)
sobely = cv2.Sobel(mblur,cv2.CV_8U,0,1,ksize=7)
edges = cv2.Canny(laplacian, 0, 50)
edges1 = cv2.Canny(sobelx, 0, 50) 
edges2 = cv2.Canny(sobely, 0, 50) 
edges = cv2.GaussianBlur(edges, (7, 7), 1.5)
plt.imshow(edges,cmap='gray')
plt.show()  
#plt.imshow(edges1,cmap='gray')
#plt.show()
#plt.imshow(edges2,cmap='gray')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-d7b969d4b5b0> in <module>()
#       7 img = cv2.imread('KB_my_pics/3.jpg',1)
#       8 #timage = cv2.imread('C:/Users/dario/Pictures/KB_my_pics/2.jpg',1)
# ----> 9 h,w = img.shape[:2]
#      10 plt.imshow(img,cmap='gray')
#      11 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
from PIL import ImageFilter
import cv2
import numpy as np
from matplotlib import pyplot as plt
import sys
# %matplotlib inline
img = cv2.imread('KB_my_pics/3.jpg',1)  
h,w = img.shape[:2]
plt.imshow(img,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-770ebc4b2e11> in <module>()
#       6 get_ipython().magic('matplotlib inline')
#       7 img = cv2.imread('KB_my_pics/3.jpg',0)
# ----> 8 h,w = img.shape[:2]
#       9 plt.imshow(img,cmap='gray')
#      10 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'shape'
